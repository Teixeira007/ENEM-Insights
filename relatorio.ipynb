# %%
import pandas as pd

# %%
enem = (
    pd.read_csv('dados/dados_enem_tratados.csv', encoding='UTF-8', delimiter=',')
)
enem
# Out:
#          NU_INSCRICAO  NU_ANO   TP_FAIXA_ETARIA TP_SEXO  \
# 0        210057943671    2022   26 anos ou mais       M
# 1        210057516120    2022   26 anos ou mais       M
# 2        210057280536    2022  Menor de 26 anos       F
# 3        210055724397    2022  Menor de 26 anos       M
# 4        210055097896    2022  Menor de 26 anos       M
# ...               ...     ...               ...     ...
# 3476100  210056389903    2022  Menor de 26 anos       M
# 3476101  210057205644    2022   26 anos ou mais       F
# 3476102  210056699189    2022  Menor de 26 anos       M
# 3476103  210056983033    2022  Menor de 26 anos       M
# 3476104  210056307777    2022  Menor de 26 anos       F
#
#                            TP_ESTADO_CIVIL TP_COR_RACA TP_NACIONALIDADE  \
# 0        Casado(a)/Mora com companheiro(a)       Preta    Brasileiro(a)
# 1        Casado(a)/Mora com companheiro(a)      Branca    Brasileiro(a)
# 2                              Solteiro(a)       Preta    Brasileiro(a)
# ...
